# %% [markdown]
# ## Group Project - Investment Case Study
#    #### Group Members:
#     -  Vinayak Bandhu
#     -  Sarathbabu Sankaran
#     -  Puneet Agarwal
#     -  Rakesh Gorai

# %% [markdown]
# # Checkpoint 1 : Data Cleaning

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###  1.1:  Importing data from companies and rounds2 datasets

# %%
#importing data from companies.txt
companies = pd.read_csv("companies.txt",sep='\t', engine = "python")

#remove unwanted characters
companies.loc[:,'permalink'] = companies['permalink'].str.encode('utf-8').str.decode('ascii', 'ignore').str.lower()
companies.loc[:,'name'] = companies['name'].str.encode('utf-8').str.decode('ascii', 'ignore').str.lower()

#importing data from rounds2.csv
rounds2   = pd.read_csv("rounds2.csv",engine = "python")

#remove unwanted characters
rounds2.loc[:,'company_permalink'] = rounds2['company_permalink'].str.encode('utf-8').str.decode('ascii','ignore').str.lower()

# %% [markdown]
#  ### 1.2:  Counting unique values and Inspecting

# %%
#count number of unique rows in companies and rounds2 dataframes
print(companies.loc[:,"permalink"].nunique())
print(rounds2.loc[:,"company_permalink"].nunique())
# Out:
# 66368
# 66368

# %%
#inspect the companies dataframe 
print(companies.shape)
print(companies.info())
print(companies.describe())
# Out:
# (66368, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 10 columns):
# permalink        66368 non-null object
# name             66367 non-null object
# homepage_url     61310 non-null object
# category_list    63220 non-null object
# status           66368 non-null object
# country_code     59410 non-null object
# state_code       57821 non-null object
# region           58338 non-null object
# city             58340 non-null object
# founded_at       51147 non-null object
# dtypes: object(10)
# memory usage: 5.1+ MB
# None
#                                 permalink   name                homepage_url  \
# count                               66368  66367                       61310
# unique                              66368  66037                       61191
# top     /organization/kezar-life-sciences  spire  http://www.askforoffer.com
# freq                                    1      4                           5
#
#        category_list     status country_code state_code       region  \
# count          63220      66368        59410      57821        58338
# unique         27296          4          137        311         1092
# top         Software  operating          USA         CA  SF Bay Area
# freq            3995      53034        37601      12900         8804
#
#                  city  founded_at
# count           58340       51147
# unique           5111        3978
# top     San Francisco  01-01-2012
# freq             3526        2730

# %%
#inspect the rounds2 dataframe
print(rounds2.shape)
print(rounds2.info())
print(rounds2.describe(include = 'all'))
# Out:
# (114949, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
# company_permalink          114949 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         31140 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          94959 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB
# None
#                company_permalink  \
# count                     114949
# unique                     66368
# top     /organization/solarflare
# freq                          19
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN
#
#                                 funding_round_permalink funding_round_type  \
# count                                            114949             114949
# unique                                           114949                 14
# top     /funding-round/ee5c816c48fef783793ff6f5571c538e            venture
# freq                                                  1              55494
# mean                                                NaN                NaN
# std                                                 NaN                NaN
# min                                                 NaN                NaN
# 25%                                                 NaN                NaN
# 50%                                                 NaN                NaN
# 75%                                                 NaN                NaN
# max                                                 NaN                NaN
#
#        funding_round_code   funded_at  raised_amount_usd
# count               31140      114949       9.495900e+04
# unique                  8        5033                NaN
# top                     A  01-01-2014                NaN
# freq                14747         779                NaN
# mean                  NaN         NaN       1.042687e+07
# std                   NaN         NaN       1.148212e+08
# min                   NaN         NaN       0.000000e+00
# 25%                   NaN         NaN       3.225000e+05
# 50%                   NaN         NaN       1.680511e+06
# 75%                   NaN         NaN       7.000000e+06
# max                   NaN         NaN       2.127194e+10

# %%
#checking for companies which are not in rounds2 dataframe
companies.loc[~companies['permalink'].isin(rounds2['company_permalink']),:]
# Out:
# Empty DataFrame
# Columns: [permalink, name, homepage_url, category_list, status, country_code, state_code, region, city, founded_at]
# Index: []

# %% [markdown]
# ### 1.3: Merging the companies and rounds2 dataframe to create master_frame dataframe

# %%
# merge the companies and rounds2 dataframe. Since the name of common column in both the dataframe is not same,
# the name of company_permalink is renamed to permalink to remove the duplication of column in master_frame
master_frame = pd.merge(companies,rounds2.rename(columns={'company_permalink':'permalink'}), how = 'inner', on = 'permalink' )

# %%
#inspect the master frame
print(master_frame.shape)
print(master_frame.info())
print(master_frame.describe(include = 'all'))
# Out:
# (114949, 15)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114949 entries, 0 to 114948
# Data columns (total 15 columns):
# permalink                  114949 non-null object
# name                       114948 non-null object
# homepage_url               108815 non-null object
# category_list              111539 non-null object
# status                     114949 non-null object
# country_code               106271 non-null object
# state_code                 104003 non-null object
# region                     104782 non-null object
# city                       104785 non-null object
# founded_at                 94428 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         31140 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          94959 non-null float64
# dtypes: float64(1), object(14)
# memory usage: 14.0+ MB
# None
#                        permalink                       name  \
# count                     114949                     114948
# unique                     66368                      66037
# top     /organization/solarflare  solarflare communications
# freq                          19                         19
# mean                         NaN                        NaN
# std                          NaN                        NaN
# min                          NaN                        NaN
# 25%                          NaN                        NaN
# 50%                          NaN                        NaN
# 75%                          NaN                        NaN
# max                          NaN                        NaN
#
#                      homepage_url  category_list     status country_code  \
# count                      108815         111539     114949       106271
# unique                      61191          27296          4          137
# top     http://www.solarflare.com  Biotechnology  operating          USA
# freq                           19           8165      90153        72308
# mean                          NaN            NaN        NaN          NaN
# std                           NaN            NaN        NaN          NaN
# min                           NaN            NaN        NaN          NaN
# 25%                           NaN            NaN        NaN          NaN
# 50%                           NaN            NaN        NaN          NaN
# 75%                           NaN            NaN        NaN          NaN
# max                           NaN            NaN        NaN          NaN
#
#        state_code       region           city  founded_at  \
# count      104003       104782         104785       94428
# unique        311         1092           5111        3978
# top            CA  SF Bay Area  San Francisco  01-01-2012
# freq        26664        19078           7422        4642
# mean          NaN          NaN            NaN         NaN
# std           NaN          NaN            NaN         NaN
# min           NaN          NaN            NaN         NaN
# 25%           NaN          NaN            NaN         NaN
# 50%           NaN          NaN            NaN         NaN
# 75%           NaN          NaN            NaN         NaN
# max           NaN          NaN            NaN         NaN
#
#                                 funding_round_permalink funding_round_type  \
# count                                            114949             114949
# unique                                           114949                 14
# top     /funding-round/ee5c816c48fef783793ff6f5571c538e            venture
# freq                                                  1              55494
# mean                                                NaN                NaN
# std                                                 NaN                NaN
# min                                                 NaN                NaN
# 25%                                                 NaN                NaN
# 50%                                                 NaN                NaN
# 75%                                                 NaN                NaN
# max                                                 NaN                NaN
#
#        funding_round_code   funded_at  raised_amount_usd
# count               31140      114949       9.495900e+04
# unique                  8        5033                NaN
# top                     A  01-01-2014                NaN
# freq                14747         779                NaN
# mean                  NaN         NaN       1.042687e+07
# std                   NaN         NaN       1.148212e+08
# min                   NaN         NaN       0.000000e+00
# 25%                   NaN         NaN       3.225000e+05
# 50%                   NaN         NaN       1.680511e+06
# 75%                   NaN         NaN       7.000000e+06
# max                   NaN         NaN       2.127194e+10

# %%
# Checking the null count in each column
master_frame.isnull().sum()
# Out:
# permalink                      0
# name                           1
# homepage_url                6134
# category_list               3410
# status                         0
# country_code                8678
# state_code                 10946
# region                     10167
# city                       10164
# founded_at                 20521
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         83809
# funded_at                      0
# raised_amount_usd          19990
# dtype: int64

# %%
#checking the null count in each row
master_frame.isnull().sum(axis = 1)
# Out:
# 0         1
# 1         1
# 2         1
# 3         5
# 4         0
# 5         2
# 6         3
# 7         1
# 8         1
# 9         1
# 10        0
# 11        1
# 12        0
# 13        1
# 14        2
# 15        1
# 16        1
# 17        4
# 18        2
# 19        2
# 20        1
# 21        1
# 22        1
# 23        2
# 24        1
# 25        1
# 26        1
# 27        1
# 28        0
# 29        1
#          ..
# 114919    1
# 114920    0
# 114921    1
# 114922    1
# 114923    1
# 114924    1
# 114925    1
# 114926    1
# 114927    2
# 114928    1
# 114929    1
# 114930    1
# 114931    0
# 114932    2
# 114933    2
# 114934    2
# 114935    2
# 114936    1
# 114937    0
# 114938    1
# 114939    1
# 114940    1
# 114941    1
# 114942    1
# 114943    1
# 114944    1
# 114945    1
# 114946    6
# 114947    1
# 114948    6
# Length: 114949, dtype: int64

# %%
#Checking the %age of null in each column
round(100* master_frame.isnull().sum()/len(master_frame.index),2)
# Out:
# permalink                   0.00
# name                        0.00
# homepage_url                5.34
# category_list               2.97
# status                      0.00
# country_code                7.55
# state_code                  9.52
# region                      8.84
# city                        8.84
# founded_at                 17.85
# funding_round_permalink     0.00
# funding_round_type          0.00
# funding_round_code         72.91
# funded_at                   0.00
# raised_amount_usd          17.39
# dtype: float64

# %%
#master_frame_temp = master_frame.drop(['funding_round_code','homepage_url','founded_at', 'funded_at', 'funding_round_permalink'],axis=1,inplace=False)
#round(100*(master_frame_temp.isnull().sum()/len(master_frame_temp.index)), 2)

# %% [markdown]
# Since raised_amount_usd has 17.39 percentage of null values and the investment analysis requires funding amount.
# Hence dropping these rows.

# %%
#dropping the rows which have null value for raised_amount_usd
#master_frame_temp = master_frame_temp[~np.isnan(master_frame_temp['raised_amount_usd'])]
master_frame_temp = master_frame[~np.isnan(master_frame['raised_amount_usd'])]

# %%
round(100*(master_frame_temp.isnull().sum()/len(master_frame_temp.index)), 2)
# Out:
# permalink                   0.00
# name                        0.00
# homepage_url                4.56
# category_list               1.10
# status                      0.00
# country_code                6.16
# state_code                  8.01
# region                      7.42
# city                        7.42
# founded_at                 16.81
# funding_round_permalink     0.00
# funding_round_type          0.00
# funding_round_code         70.34
# funded_at                   0.00
# raised_amount_usd           0.00
# dtype: float64

# %%
#master_frame_temp = master_frame_temp[master_frame_temp.isnull().sum(axis=1) <5]

# %%
#round(100*(master_frame_temp.isnull().sum()/len(master_frame_temp.index)), 2)

# %% [markdown]
# #### Change the unit of columns:
# Convert the unit of the `raised_amount_usd` column from `USD` to `million USD`.

# %%
master_frame_temp['raised_amount_mn_usd'] = master_frame_temp['raised_amount_usd'].apply(lambda x : x/1000000)

# %% [markdown]
# # Checkpoint 2: Funding Type Analysis

# %% [markdown]
# ### 2.1: Average funding in Investment Types

# %%
group_by_funding_round_type = master_frame_temp.groupby('funding_round_type')
average_frtype = pd.DataFrame(group_by_funding_round_type['raised_amount_mn_usd'].mean())

# %%
average_frtype.loc[['venture','angel','seed','private_equity']].sort_values(by = 'raised_amount_mn_usd', ascending = False)
# Out:
#                     raised_amount_mn_usd
# funding_round_type
# private_equity                 73.308593
# venture                        11.748949
# angel                           0.958694
# seed                            0.719818

# %% [markdown]
# Here the `venture` is the second highest investment type with raised_amount_mn_usd and falls under the 5 to 15 M USD window of Spark Funds. Hence this is the most suitable investment type for Spark Funds.

# %%
master_frame_country = master_frame_temp.loc[master_frame_temp['funding_round_type'] == 'venture', :]

# %%
#Check the null percentage in each column in the master_frame_country dataframe
round(100*(master_frame_country.isnull().sum()/len(master_frame_country.index)), 2)
# Out:
# permalink                   0.00
# name                        0.00
# homepage_url                5.19
# category_list               1.00
# status                      0.00
# country_code                4.21
# state_code                  5.70
# region                      5.40
# city                        5.40
# founded_at                 19.17
# funding_round_permalink     0.00
# funding_round_type          0.00
# funding_round_code         44.17
# funded_at                   0.00
# raised_amount_usd           0.00
# raised_amount_mn_usd        0.00
# dtype: float64

# %%
#Check the count null values in each column in master_frame_country dataframe
master_frame_country.isnull().sum()
# Out:
# permalink                      0
# name                           0
# homepage_url                2608
# category_list                502
# status                         0
# country_code                2117
# state_code                  2861
# region                      2713
# city                        2713
# founded_at                  9631
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         22185
# funded_at                      0
# raised_amount_usd              0
# raised_amount_mn_usd           0
# dtype: int64

# %%
#Checking the number of rows for which all the state_code, region, city and country_code columns are null
len(master_frame_country.loc[(master_frame_temp['region'].isnull() & master_frame_temp['city'].isnull() & master_frame_temp['state_code'].isnull() & master_frame_temp['country_code'].isnull())].index)
# Out:
# 2117

# %% [markdown]
# Since the number of rows for which all the state_code, region, city and country_code columns are null is `2117` which is same as the number of number of rows with null value in country_code. Hence it is not possible to impute date from any of these columns to country_code. Hence dropping the country_code rows with null value rather than imputing it with the mode

# %% [markdown]
# # Checkpoint 3: Country Analysis

# %% [markdown]
# ### 3.1: Cleaning the dataset for unvailable country code

# %%
#dropping the rows with null values in country_code column.
master_frame_country = master_frame_country[~(master_frame_country['country_code'].isnull())]

# %%
#Checking the number of null values in each column in master_frame_country dataframe.
master_frame_country.isnull().sum()
# Out:
# permalink                      0
# name                           0
# homepage_url                2175
# category_list                302
# status                         0
# country_code                   0
# state_code                   744
# region                       596
# city                         596
# founded_at                  8551
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         21294
# funded_at                      0
# raised_amount_usd              0
# raised_amount_mn_usd           0
# dtype: int64

# %%
#Checking the percentage of null values in each column in master_frame_country dataframe.
round(100*(master_frame_country.isnull().sum()/len(master_frame_country.index)), 2)
# Out:
# permalink                   0.00
# name                        0.00
# homepage_url                4.52
# category_list               0.63
# status                      0.00
# country_code                0.00
# state_code                  1.55
# region                      1.24
# city                        1.24
# founded_at                 17.77
# funding_round_permalink     0.00
# funding_round_type          0.00
# funding_round_code         44.26
# funded_at                   0.00
# raised_amount_usd           0.00
# raised_amount_mn_usd        0.00
# dtype: float64

# %%
#master_frame_country = master_frame_country.drop(['state_code','region', 'city'],axis=1,inplace=False)
#round(100*(master_frame_country.isnull().sum()/len(master_frame_country.index)), 2)

# %%
#master_frame_country.isnull().sum()

# %% [markdown]
# ### 3.2: Grouping countries on the basis of Total funding

# %%
#Grouping the dataframe by country_code and calculating the total investment in each country
group_by_country = master_frame_country.groupby('country_code')

#Sorting the countries based on the total investment amount from top to down
total_amount_per_country = pd.DataFrame(group_by_country['raised_amount_mn_usd'].sum()).sort_values(by = "raised_amount_mn_usd",ascending = False)

# %%
#Finding the top 9 countries with highest amount of investment
top9 = total_amount_per_country.iloc[:9,:]
top9
# Out:
#               raised_amount_mn_usd
# country_code
# USA                  422510.842796
# CHN                   39835.418773
# GBR                   20245.627416
# IND                   14391.858718
# CAN                    9583.332317
# FRA                    7259.536732
# ISR                    6907.514579
# DEU                    6346.959822
# JPN                    3363.676611

# %% [markdown]
# # Checkpoint 4: Sector Analysis 1

# %% [markdown]
# In the top9 dataframe, the top 3 countries with English as an official language are `USA`, `GBR` and `IND`.

# %%
#Creating a new data frame sector_df with the 3 countries USA, GBR and IND
sector_df = master_frame_country.loc[(master_frame_country['country_code'] == 'USA') | (master_frame_country['country_code'] == 'GBR') | (master_frame_country['country_code'] == 'IND')]

# %%
sector_df.isnull().sum()
# Out:
# permalink                      0
# name                           0
# homepage_url                1857
# category_list                215
# status                         0
# country_code                   0
# state_code                    73
# region                       158
# city                         158
# founded_at                  6326
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         17816
# funded_at                      0
# raised_amount_usd              0
# raised_amount_mn_usd           0
# dtype: int64

# %%
round(100*(sector_df.isnull().sum()/len(sector_df.index)), 2)
# Out:
# permalink                   0.00
# name                        0.00
# homepage_url                4.76
# category_list               0.55
# status                      0.00
# country_code                0.00
# state_code                  0.19
# region                      0.40
# city                        0.40
# founded_at                 16.21
# funding_round_permalink     0.00
# funding_round_type          0.00
# funding_round_code         45.66
# funded_at                   0.00
# raised_amount_usd           0.00
# raised_amount_mn_usd        0.00
# dtype: float64

# %%
#Import mapping.csv file
mapping = pd.read_csv('mapping.csv')
len(mapping.index)
# Out:
# 688

# %%
#Extracting primary sectors from category_list and adding a new column 'primary_sector' with these values.
sector_primary = sector_df['category_list'].str.split('|',  expand = True)
sector_df['primary_sector'] = sector_primary.iloc[:,0]

# %%
mapping.iloc[:,0]
# Out:
# 0                             NaN
# 1                              3D
# 2                     3D Printing
# 3                   3D Technology
# 4                      Accounting
# 5                Active Lifestyle
# 6                    Ad Targeting
# 7              Advanced Materials
# 8                Adventure Travel
# 9                     Advertising
# 10          Advertising Exchanges
# 11           Advertising Networks
# 12          Advertising Platforms
# 13                         Advice
# 14                      Aerospace
# 15                    Agriculture
# 16          Air Pollution Control
# 17                     Algorithms
# 18                    All Markets
# 19                   All Students
# 20            Alter0tive Medicine
# 21                         Alumni
# 22                       A0lytics
# 23                        Android
# 24                         Angels
# 25                    Animal Feed
# 26     Anything Capital Intensive
# 27                  App Discovery
# 28                  App Marketing
# 29                     App Stores
#                   ...
# 658                     Usability
# 659        User Experience Design
# 660                User Interface
# 661                     Utilities
# 662       Vending and Concessions
# 663               Venture Capital
# 664                     Veteri0ry
# 665                         Video
# 666            Video Conferencing
# 667                   Video Games
# 668               Video on Demand
# 669               Video Streaming
# 670            Virtual Workforces
# 671                          VoIP
# 672               Waste Ma0gement
# 673                         Watch
# 674                         Water
# 675            Water Purification
# 676                     Wearables
# 677                  Web Browsers
# 678                    Web Design
# 679               Web Development
# 680                   Web Hosting
# 681                     Web Tools
# 682                      Weddings
# 683                     Wholesale
# 684              Wine And Spirits
# 685                      Wireless
# 686                         Women
# 687                  Young Adults
# Name: category_list, Length: 688, dtype: object

# %%
#Cleaning the mapping dataframe. The 'na' in each category is replaced with '0' in the dataframe.
#Hence changing the '0' to 'na' again.
mapping['category_list'] = mapping['category_list'].str.replace('0', 'na', regex=False)

# %%
mapping['category_list']
# Out:
# 0                             NaN
# 1                              3D
# 2                     3D Printing
# 3                   3D Technology
# 4                      Accounting
# 5                Active Lifestyle
# 6                    Ad Targeting
# 7              Advanced Materials
# 8                Adventure Travel
# 9                     Advertising
# 10          Advertising Exchanges
# 11           Advertising Networks
# 12          Advertising Platforms
# 13                         Advice
# 14                      Aerospace
# 15                    Agriculture
# 16          Air Pollution Control
# 17                     Algorithms
# 18                    All Markets
# 19                   All Students
# 20           Alternative Medicine
# 21                         Alumni
# 22                      Analytics
# 23                        Android
# 24                         Angels
# 25                    Animal Feed
# 26     Anything Capital Intensive
# 27                  App Discovery
# 28                  App Marketing
# 29                     App Stores
#                   ...
# 658                     Usability
# 659        User Experience Design
# 660                User Interface
# 661                     Utilities
# 662       Vending and Concessions
# 663               Venture Capital
# 664                    Veterinary
# 665                         Video
# 666            Video Conferencing
# 667                   Video Games
# 668               Video on Demand
# 669               Video Streaming
# 670            Virtual Workforces
# 671                          VoIP
# 672              Waste Management
# 673                         Watch
# 674                         Water
# 675            Water Purification
# 676                     Wearables
# 677                  Web Browsers
# 678                    Web Design
# 679               Web Development
# 680                   Web Hosting
# 681                     Web Tools
# 682                      Weddings
# 683                     Wholesale
# 684              Wine And Spirits
# 685                      Wireless
# 686                         Women
# 687                  Young Adults
# Name: category_list, Length: 688, dtype: object

# %%
#normalizing the mapping dataframe so that merge operation can be done appropriately.
mapping = pd.melt(mapping, id_vars = ["category_list"], var_name = "main_sector")

# %%
#Removing the unwanted rows which doesn't provide ant mapping information
mapping = mapping[~(mapping['value'] == 0)]

#Dropping the value column, since it is not useful.
mapping.drop(['value'],axis=1,inplace=True)

# %%
len(mapping.index)
# Out:
# 688

# %%
#merging the sector data with main sector mapping
sector_df = pd.merge(sector_df,mapping.rename(columns={'category_list':'primary_sector'}), how = 'inner', on = 'primary_sector' )

# %%
sector_df
# Out:
#                                             permalink  \
# 0                                 /organization/-fame
# 1                                 /organization/90min
# 2                                 /organization/90min
# 3                                 /organization/90min
# 4                       /organization/all-def-digital
# 5                           /organization/audiosocket
# 6                           /organization/audiosocket
# 7                           /organization/audiosocket
# 8                                /organization/babble
# 9                                /organization/babble
# 10                               /organization/babble
# 11                               /organization/bedloo
# 12                               /organization/bedloo
# 13                               /organization/bedloo
# 14                           /organization/chefs-feed
# 15                  /organization/cipher-online-media
# 16                   /organization/curtco-media-group
# 17                        /organization/genius-monkey
# 18                          /organization/glass-media
# 19             /organization/globalbased-technologies
# 20                       /organization/huffingtonpost
# 21                       /organization/huffingtonpost
# 22                       /organization/huffingtonpost
# 23                    /organization/manas-informatics
# 24     /organization/marine-construction-technologies
# 25                            /organization/matchmine
# 26               /organization/media-group-of-america
# 27                            /organization/mediabong
# 28                      /organization/newscorporation
# 29                              /organization/nokeena
# ...                                               ...
# 38823               /organization/streamline-alliance
# 38824                            /organization/swajal
# 38825                 /organization/tactus-technology
# 38826                 /organization/tactus-technology
# 38827                           /organization/tap-in2
# 38828                          /organization/thisnext
# 38829                          /organization/thisnext
# 38830                          /organization/thisnext
# 38831                           /organization/thredhq
# 38832                               /organization/vee
# 38833                          /organization/treatsie
# 38834                          /organization/treatsie
# 38835                       /organization/trestletree
# 38836            /organization/wizrocket-technologies
# 38837                            /organization/truist
# 38838                            /organization/truist
# 38839           /organization/us-forming-technologies
# 38840                    /organization/user-interface
# 38841                      /organization/vector-watch
# 38842                            /organization/washio
# 38843                             /organization/yapta
# 38844                             /organization/yapta
# 38845                             /organization/yapta
# 38846                             /organization/yapta
# 38847                             /organization/yapta
# 38848                             /organization/yapta
# 38849                             /organization/yapta
# 38850                             /organization/yapta
# 38851                            /organization/ziftit
# 38852                      /organization/zonarsystems
#
#                                    name                        homepage_url  \
# 0                                 #fame                  http://livfame.com
# 1                                 90min                http://www.90min.com
# 2                                 90min                http://www.90min.com
# 3                                 90min                http://www.90min.com
# 4                       all def digital            http://alldefdigital.com
# 5                           audiosocket              http://audiosocket.com
# 6                           audiosocket              http://audiosocket.com
# 7                           audiosocket              http://audiosocket.com
# 8                                babble               http://www.babble.com
# 9                                babble               http://www.babble.com
# 10                               babble               http://www.babble.com
# 11                               bedloo                   http://bedloo.com
# 12                               bedloo                   http://bedloo.com
# 13                               bedloo                   http://bedloo.com
# 14                            chefsfeed            http://www.chefsfeed.com
# 15                  cipher online media                                 NaN
# 16                   curtco media group                                 NaN
# 17                        genius monkey             http://geniusmonkey.com
# 18                          glass media          http://www.glass-media.com
# 19             globalbased technologies                                 NaN
# 20                  the huffington post       http://www.huffingtonpost.com
# 21                  the huffington post       http://www.huffingtonpost.com
# 22                  the huffington post       http://www.huffingtonpost.com
# 23                     manas informatic               http://www.topnews.in
# 24     marine construction technologies           http://marinecontech.org/
# 25                            matchmine                http://matchmine.com
# 26               media group of america                    http://mgofa.com
# 27                            mediabong            http://www.mediabong.com
# 28                            news corp             http://www.newscorp.com
# 29                     ankeena networks              http://www.ankeena.com
# ...                                 ...                                 ...
# 38823               streamline alliance  http://www.streamline-alliance.com
# 38824                            swajal                   http://swajal.in/
# 38825                 tactus technology     http://www.tactustechnology.com
# 38826                 tactus technology     http://www.tactustechnology.com
# 38827                           tap.in2               http://www.tapin2.co/
# 38828                          thisnext             http://www.thisnext.com
# 38829                          thisnext             http://www.thisnext.com
# 38830                          thisnext             http://www.thisnext.com
# 38831                           thredhq                https://thredhq.com/
# 38832                               vee               http://www.getvee.com
# 38833                          treatsie             http://www.treatsie.com
# 38834                          treatsie             http://www.treatsie.com
# 38835                       trestletree         http://www.trestletree.com/
# 38836                         clevertap              https://clevertap.com/
# 38837                            truist                   http://truist.com
# 38838                            truist                   http://truist.com
# 38839           us forming technologies                                 NaN
# 38840                    user interface        http://www.userinterface.com
# 38841                      vector watch         http://www.vectorwatch.com/
# 38842                            washio            http://www.getwashio.com
# 38843                             yapta                http://www.yapta.com
# 38844                             yapta                http://www.yapta.com
# 38845                             yapta                http://www.yapta.com
# 38846                             yapta                http://www.yapta.com
# 38847                             yapta                http://www.yapta.com
# 38848                             yapta                http://www.yapta.com
# 38849                             yapta                http://www.yapta.com
# 38850                             yapta                http://www.yapta.com
# 38851                            ziftit               http://www.ziftit.com
# 38852                     zonar systems         http://www.zonarsystems.com
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1                Media|News|Publishing|Soccer|Sports  operating          GBR
# 2                Media|News|Publishing|Soccer|Sports  operating          GBR
# 3                Media|News|Publishing|Soccer|Sports  operating          GBR
# 4                                              Media  operating          USA
# 5                             Media|Music|Technology  operating          USA
# 6                             Media|Music|Technology  operating          USA
# 7                             Media|Music|Technology  operating          USA
# 8                               Media|News|Parenting   acquired          USA
# 9                               Media|News|Parenting   acquired          USA
# 10                              Media|News|Parenting   acquired          USA
# 11                               Media|News|Software  operating          USA
# 12                               Media|News|Software  operating          USA
# 13                               Media|News|Software  operating          USA
# 14               Media|Mobile|Restaurants|Technology  operating          USA
# 15                               Media|News|Security  operating          USA
# 16                         Media|Publishing|Services     closed          USA
# 17                                             Media  operating          USA
# 18                                             Media     closed          USA
# 19                          Media|Technology|Trading  operating          USA
# 20                             Media|News|Publishing   acquired          USA
# 21                             Media|News|Publishing   acquired          USA
# 22                             Media|News|Publishing   acquired          USA
# 23                                        Media|News  operating          IND
# 24                                             Media  operating          USA
# 25            Media|News|Reviews and Recommendations     closed          USA
# 26                                             Media  operating          USA
# 27                       Media|Semantic Search|Video  operating          USA
# 28                             Media|News|Publishing        ipo          USA
# 29                                    Media|Software   acquired          USA
# ...                                              ...        ...          ...
# 38823                                    Procurement  operating          USA
# 38824                             Water Purification  operating          IND
# 38825                     Human Computer Interaction  operating          USA
# 38826                     Human Computer Interaction  operating          USA
# 38827          Music Venues|Software|Sports Stadiums  operating          USA
# 38828                     Social Buying|Social Media  operating          USA
# 38829                     Social Buying|Social Media  operating          USA
# 38830                     Social Buying|Social Media  operating          USA
# 38831   Social + Mobile + Local|Social Network Media  operating          USA
# 38832               Social + Mobile + Local|Software  operating          IND
# 38833  Gift Exchange|Online Shopping|Specialty Foods  operating          USA
# 38834  Gift Exchange|Online Shopping|Specialty Foods  operating          USA
# 38835   Consumer Behavior|Employer Benefits Programs   acquired          USA
# 38836        Consumer Behavior|Mobile Analytics|SaaS  operating          USA
# 38837          Humanitarian|Human Resources|Software   acquired          USA
# 38838          Humanitarian|Human Resources|Software   acquired          USA
# 38839       Mechanical Solutions|Services|Technology  operating          USA
# 38840                                 User Interface  operating          USA
# 38841                                Watch|Wearables  operating          GBR
# 38842                             Service Industries  operating          USA
# 38843                 Tracking|Transportation|Travel  operating          USA
# 38844                 Tracking|Transportation|Travel  operating          USA
# 38845                 Tracking|Transportation|Travel  operating          USA
# 38846                 Tracking|Transportation|Travel  operating          USA
# 38847                 Tracking|Transportation|Travel  operating          USA
# 38848                 Tracking|Transportation|Travel  operating          USA
# 38849                 Tracking|Transportation|Travel  operating          USA
# 38850                 Tracking|Transportation|Travel  operating          USA
# 38851                       Gift Registries|Shopping     closed          USA
# 38852                       Task Management|Tracking  operating          USA
#
#       state_code            region             city  founded_at  \
# 0             16            Mumbai           Mumbai         NaN
# 1             H9            London           London  01-01-2011
# 2             H9            London           London  01-01-2011
# 3             H9            London           London  01-01-2011
# 4             CA       Los Angeles      Los Angeles         NaN
# 5             WA           Seattle          Seattle  01-05-2008
# 6             WA           Seattle          Seattle  01-05-2008
# 7             WA           Seattle          Seattle  01-05-2008
# 8             NY     New York City         New York  01-12-2006
# 9             NY     New York City         New York  01-12-2006
# 10            NY     New York City         New York  01-12-2006
# 11            CA       Los Angeles    Thousand Oaks  01-10-2011
# 12            CA       Los Angeles    Thousand Oaks  01-10-2011
# 13            CA       Los Angeles    Thousand Oaks  01-10-2011
# 14            CA       SF Bay Area    San Francisco  01-01-2012
# 15            DC  Washington, D.C.       Washington         NaN
# 16            CA       Los Angeles           Malibu         NaN
# 17            AZ           Phoenix            Tempe         NaN
# 18            TX            Dallas           Dallas  01-01-2012
# 19            UT    Salt Lake City            Provo         NaN
# 20            NY     New York City         New York  09-05-2005
# 21            NY     New York City         New York  09-05-2005
# 22            NY     New York City         New York  09-05-2005
# 23            23            Mohali           Mohali  05-05-2007
# 24            WA           Seattle          Seattle  01-01-2012
# 25            MA            Boston          Needham  01-01-2007
# 26            DC  Washington, D.C.       Washington  01-01-2013
# 27            NY     New York City         New York  30-05-2011
# 28            NY     New York City         New York  01-01-2013
# 29            CA       SF Bay Area      Santa Clara  01-01-2008
# ...          ...               ...              ...         ...
# 38823         FL      Jacksonville      Kenansville  05-01-1999
# 38824         10         New Delhi          Gurgaon  01-01-2011
# 38825         CA       SF Bay Area          Fremont  01-01-2008
# 38826         CA       SF Bay Area          Fremont  01-01-2008
# 38827         OH         Cleveland        Cleveland  16-09-2011
# 38828         CA       Los Angeles     Santa Monica  01-12-2005
# 38829         CA       Los Angeles     Santa Monica  01-12-2005
# 38830         CA       Los Angeles     Santa Monica  01-12-2005
# 38831         CA       SF Bay Area         Berkeley  01-01-2012
# 38832         36         New Delhi            Noida  23-04-2014
# 38833         AR       Little Rock         Maumelle  01-09-2012
# 38834         AR       Little Rock         Maumelle  01-09-2012
# 38835         AR      Fayetteville     Fayetteville  01-01-2001
# 38836         CA       SF Bay Area        Palo Alto  24-05-2013
# 38837         DC  Washington, D.C.       Washington  01-01-2008
# 38838         DC  Washington, D.C.       Washington  01-01-2008
# 38839         MI      Grand Rapids     Grand Rapids         NaN
# 38840         CA       Bakersfield  California City         NaN
# 38841         H9            London           London  01-01-2013
# 38842         CA       Los Angeles      Los Angeles  01-01-2013
# 38843         WA           Seattle          Seattle  01-07-2007
# 38844         WA           Seattle          Seattle  01-07-2007
# 38845         WA           Seattle          Seattle  01-07-2007
# 38846         WA           Seattle          Seattle  01-07-2007
# 38847         WA           Seattle          Seattle  01-07-2007
# 38848         WA           Seattle          Seattle  01-07-2007
# 38849         WA           Seattle          Seattle  01-07-2007
# 38850         WA           Seattle          Seattle  01-07-2007
# 38851         CA         San Diego        San Diego  01-02-2011
# 38852         WA           Seattle          Seattle  01-01-2001
#
#                                funding_round_permalink funding_round_type  \
# 0      /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1      /funding-round/21a2cbf6f2fb2a1c2a61e04bf930dfe6            venture
# 2      /funding-round/bd626ed022f5c66574b1afe234f3c90d            venture
# 3      /funding-round/fd4b15e8c97ee2ffc0acccdbe1a98810            venture
# 4      /funding-round/452a2342fe720285c3b92e9bd927d9ba            venture
# 5      /funding-round/0959f59e3a89bc8db8c6ed9c646349fd            venture
# 6      /funding-round/4e3a53eec6c609943df752206070b23f            venture
# 7      /funding-round/bc0b412cf2fa7b739e4105ad756b47a4            venture
# 8      /funding-round/43cc678b39be3e684bb88501af05ff9b            venture
# 9      /funding-round/5fdb3dbeeb6eea0243702adc372130f3            venture
# 10     /funding-round/9948a4b334b8988c2a5e00bc8b4be3ec            venture
# 11     /funding-round/50155d27414ab5e0c24aa827281499f3            venture
# 12     /funding-round/566f530f89904c91851c923431d83f33            venture
# 13     /funding-round/e393b61f25149d58470db69a1d719999            venture
# 14     /funding-round/adca195749ae9ace84684723fbe75e5b            venture
# 15     /funding-round/ac336eb85452113b39adb1e2e108e403            venture
# 16     /funding-round/80b0bf675ff33360862ae107182c7d90            venture
# 17     /funding-round/6651af18e8cec80b5df168d2e28cecb2            venture
# 18     /funding-round/cb7074009f3bd0becbebcdf08ed63a4e            venture
# 19     /funding-round/cb89639fe33d140174d9c8936cb98dd1            venture
# 20     /funding-round/7f05940c4d2dfecb8e50a0e5720e5065            venture
# 21     /funding-round/9241ae16e08df17ebdc064e49e23035a            venture
# 22     /funding-round/f92081e559b2405ef9f83074d980c3b1            venture
# 23     /funding-round/719e50301803d3918ffa558fc877e41c            venture
# 24     /funding-round/9a549453415fd1711a34f51c9abca9e3            venture
# 25     /funding-round/41ac526630da57ad6eb9d02431b17657            venture
# 26     /funding-round/048d7be2b85a3b017177b4d9b0f25faf            venture
# 27     /funding-round/9282890ca87072025dc1807f400acee6            venture
# 28     /funding-round/8f6d7c4592e43e91e8688ba342bffcb7            venture
# 29     /funding-round/9225f2db6b1b74892d5de6a8744b94ea            venture
# ...                                                ...                ...
# 38823  /funding-round/8e9a810c4709bfb9ca41d4efb9d917ef            venture
# 38824  /funding-round/aec61eeb145ab8ba222113df16c83fc4            venture
# 38825  /funding-round/0afeb81fab58fd5b03c9a64ec30b4cc4            venture
# 38826  /funding-round/e48e5b726d85e0da59ecad0b8daf0caa            venture
# 38827  /funding-round/66fb1cd68c418f29fee73a41c5ea375d            venture
# 38828  /funding-round/3ba5a2f756c9754968fc1c1638f4f415            venture
# 38829  /funding-round/592259ebb95e05fd04e1bdc021a9d080            venture
# 38830  /funding-round/e4b456b224280682adc488e9a503c40d            venture
# 38831  /funding-round/54166cbfbb75fb604c17a94f2205570e            venture
# 38832  /funding-round/3538ad48c1b16d95f34ce0900b392807            venture
# 38833  /funding-round/08021504ca24e678c2ab8e3695187390            venture
# 38834  /funding-round/a36427f3d944bc1446e51258f047fe32            venture
# 38835  /funding-round/5d5eeb4e64f1eeba0cda3d0cfd122d7d            venture
# 38836  /funding-round/195738852853780cc8f1220ba6fb761d            venture
# 38837  /funding-round/20d2bf826854b7a3399fd7e0c717a60e            venture
# 38838  /funding-round/349668bb06e4b82fc5aeb08a474db725            venture
# 38839  /funding-round/4eb26faeb695b50bf92e4c43f1bae954            venture
# 38840  /funding-round/ade267714c6ee533323f46a25b2db237            venture
# 38841  /funding-round/b010e14f723a45d5c8fadb5a857c620b            venture
# 38842  /funding-round/59026d26012c63b42fa2984c8f3c41ec            venture
# 38843  /funding-round/0b1092058a5496f5a0f1e7ed0bbead80            venture
# 38844  /funding-round/14d131aad88a6ac85915fbdcfc35489f            venture
# 38845  /funding-round/1e42b58b81c24265feb64cf55c79671d            venture
# 38846  /funding-round/2bef2981d0db9747630882cc91e42ba5            venture
# 38847  /funding-round/67e2a4f223ba195d75c516c02157e269            venture
# 38848  /funding-round/b1777df10578e852be3afbe3bc325435            venture
# 38849  /funding-round/ed75e1064eb8b50c01c2e0b691ca9f1e            venture
# 38850  /funding-round/fc066baf3121b060b574214612a6c946            venture
# 38851  /funding-round/d5713b26dbc5e0c65ccc426377449435            venture
# 38852  /funding-round/f0126dbea5d6075d8d4a1c2d106d9eca            venture
#
#       funding_round_code   funded_at  raised_amount_usd  raised_amount_mn_usd  \
# 0                      B  05-01-2015         10000000.0             10.000000
# 1                    NaN  06-10-2015         15000000.0             15.000000
# 2                    NaN  07-05-2013          5800000.0              5.800000
# 3                    NaN  26-03-2014         18000000.0             18.000000
# 4                      A  06-08-2014          5000000.0              5.000000
# 5                    NaN  02-05-2013           650000.0              0.650000
# 6                      A  02-09-2009           750000.0              0.750000
# 7                    NaN  15-02-2012          1582300.0              1.582300
# 8                      A  05-02-2009          2000000.0              2.000000
# 9                      A  12-05-2009          1250000.0              1.250000
# 10                     B  21-05-2010          3000000.0              3.000000
# 11                   NaN  15-09-2012           657589.0              0.657589
# 12                   NaN  27-09-2013           412500.0              0.412500
# 13                   NaN  10-06-2013           848000.0              0.848000
# 14                     A  26-02-2015          5000000.0              5.000000
# 15                   NaN  02-04-2015          1349999.0              1.349999
# 16                   NaN  21-05-2003        100000000.0            100.000000
# 17                   NaN  17-03-2015          2000000.0              2.000000
# 18                   NaN  01-04-2015            30000.0              0.030000
# 19                   NaN  07-01-2009          3660942.0              3.660942
# 20                     A  01-08-2006          5000000.0              5.000000
# 21                     B  01-09-2007          5000000.0              5.000000
# 22                     C  01-12-2008         25000000.0             25.000000
# 23                   NaN  02-02-2008           160000.0              0.160000
# 24                   NaN  17-04-2015           125000.0              0.125000
# 25                     A  01-09-2007         10000000.0             10.000000
# 26                   NaN  07-01-2015          1500000.0              1.500000
# 27                     B  13-05-2015          5000000.0              5.000000
# 28                   NaN  08-01-2010         12500000.0             12.500000
# 29                     A  08-08-2008          9400000.0              9.400000
# ...                  ...         ...                ...                   ...
# 38823                  A  01-01-2008          1000000.0              1.000000
# 38824                  A  03-08-2015          1200000.0              1.200000
# 38825                  B  02-01-2014         17900000.0             17.900000
# 38826                  A  21-12-2011          6000000.0              6.000000
# 38827                NaN  07-07-2015           525000.0              0.525000
# 38828                  B  01-01-2008          5000000.0              5.000000
# 38829                  C  28-01-2010          1199999.0              1.199999
# 38830                  A  01-01-2006          2500000.0              2.500000
# 38831                  A  18-09-2013          5000000.0              5.000000
# 38832                NaN  06-11-2014          1000000.0              1.000000
# 38833                NaN  10-11-2015            25000.0              0.025000
# 38834                NaN  08-10-2013           300000.0              0.300000
# 38835                  B  04-06-2004          4000000.0              4.000000
# 38836                  A  03-08-2015          8000000.0              8.000000
# 38837                NaN  30-10-2008           900000.0              0.900000
# 38838                  B  27-10-2005          3800000.0              3.800000
# 38839                NaN  31-12-2013           400500.0              0.400500
# 38840                  A  24-01-2001          8250000.0              8.250000
# 38841                NaN  25-11-2015          5000000.0              5.000000
# 38842                  A  09-06-2014         10500000.0             10.500000
# 38843                  A  01-07-2007          2300000.0              2.300000
# 38844                  D  13-11-2013          2000000.0              2.000000
# 38845                  B  12-12-2008          2700000.0              2.700000
# 38846                NaN  20-07-2011          5000000.0              5.000000
# 38847                NaN  29-12-2010          3500000.0              3.500000
# 38848                  D  22-07-2013          4220000.0              4.220000
# 38849                  C  25-06-2009          2000000.0              2.000000
# 38850                NaN  29-07-2015          1786563.0              1.786563
# 38851                NaN  09-07-2013          4000000.0              4.000000
# 38852                NaN  08-07-2015         50000000.0             50.000000
#
#                    primary_sector                              main_sector
# 0                           Media                            Entertainment
# 1                           Media                            Entertainment
# 2                           Media                            Entertainment
# 3                           Media                            Entertainment
# 4                           Media                            Entertainment
# 5                           Media                            Entertainment
# 6                           Media                            Entertainment
# 7                           Media                            Entertainment
# 8                           Media                            Entertainment
# 9                           Media                            Entertainment
# 10                          Media                            Entertainment
# 11                          Media                            Entertainment
# 12                          Media                            Entertainment
# 13                          Media                            Entertainment
# 14                          Media                            Entertainment
# 15                          Media                            Entertainment
# 16                          Media                            Entertainment
# 17                          Media                            Entertainment
# 18                          Media                            Entertainment
# 19                          Media                            Entertainment
# 20                          Media                            Entertainment
# 21                          Media                            Entertainment
# 22                          Media                            Entertainment
# 23                          Media                            Entertainment
# 24                          Media                            Entertainment
# 25                          Media                            Entertainment
# 26                          Media                            Entertainment
# 27                          Media                            Entertainment
# 28                          Media                            Entertainment
# 29                          Media                            Entertainment
# ...                           ...                                      ...
# 38823                 Procurement                                   Others
# 38824          Water Purification               Cleantech / Semiconductors
# 38825  Human Computer Interaction                                   Others
# 38826  Human Computer Interaction                                   Others
# 38827                Music Venues                            Entertainment
# 38828               Social Buying  Social, Finance, Analytics, Advertising
# 38829               Social Buying  Social, Finance, Analytics, Advertising
# 38830               Social Buying  Social, Finance, Analytics, Advertising
# 38831     Social + Mobile + Local  Social, Finance, Analytics, Advertising
# 38832     Social + Mobile + Local  Social, Finance, Analytics, Advertising
# 38833               Gift Exchange                                   Others
# 38834               Gift Exchange                                   Others
# 38835           Consumer Behavior  Social, Finance, Analytics, Advertising
# 38836           Consumer Behavior  Social, Finance, Analytics, Advertising
# 38837                Humanitarian                                   Others
# 38838                Humanitarian                                   Others
# 38839        Mechanical Solutions               Cleantech / Semiconductors
# 38840              User Interface                                   Others
# 38841                       Watch                                   Others
# 38842          Service Industries                                   Others
# 38843                    Tracking                                   Others
# 38844                    Tracking                                   Others
# 38845                    Tracking                                   Others
# 38846                    Tracking                                   Others
# 38847                    Tracking                                   Others
# 38848                    Tracking                                   Others
# 38849                    Tracking                                   Others
# 38850                    Tracking                                   Others
# 38851             Gift Registries                                   Others
# 38852             Task Management                                   Others
#
# [38853 rows x 18 columns]

# %% [markdown]
# # Checkpoint 5: Sector Analysis 2

# %%
#Data frame D1 for country USA and funding amount between 5 and 15 M USD.
#Two new columns are added Total Amount Invested and Total count of Investments
D1 = sector_df.loc[(sector_df['country_code'] == 'USA') & (sector_df['raised_amount_mn_usd'] >= 5) & (sector_df['raised_amount_mn_usd'] <= 15)]
D1['Total Amount Invested'] = D1_groupBy['raised_amount_mn_usd'].transform('sum')
D1['Total count of Investments'] = D1_groupBy['raised_amount_mn_usd'].transform('count')

# %%
#Data frame D2 for country GBR and funding amount between 5 and 15 M USD.
#Two new columns are added Total Amount Invested and Total count of Investments
D2 = sector_df.loc[(sector_df['country_code'] == 'GBR') & (sector_df['raised_amount_mn_usd'] >= 5) & (sector_df['raised_amount_mn_usd'] <= 15)]
D2['Total Amount Invested'] = D2_groupBy['raised_amount_mn_usd'].transform('sum')
D2['Total count of Investments'] = D2_groupBy['raised_amount_mn_usd'].transform('count')
D2

# %%
#Data frame D3 for country IND and funding amount between 5 and 15 M USD.
#Two new columns are added Total Amount Invested and Total count of Investments
D3 = sector_df.loc[(sector_df['country_code'] == 'IND') & (sector_df['raised_amount_mn_usd'] >= 5) & (sector_df['raised_amount_mn_usd'] <= 15)]
D3['Total Amount Invested'] = D3.groupby('main_sector')['raised_amount_mn_usd'].transform('sum')
D3['Total count of Investments'] = D3.groupby('main_sector')['raised_amount_mn_usd'].transform('count')
D3

# %%
#Total number of investments (count) and Total amount of investment (USD) of USA
print(D1['raised_amount_usd'].count())
print(D1['raised_amount_usd'].sum())
# Out:
# 108083.057956
# 12098
# main_sector
# Others                                     2950
# Social, Finance, Analytics, Advertising    2714
# Cleantech / Semiconductors                 2300
# News, Search and Messaging                 1582
# Health                                      909
# Manufacturing                               799
# Entertainment                               591
# Automotive & Sports                         167
# Blanks                                       86
# Name: raised_amount_mn_usd, dtype: int64

# %%
#Total number of investments (count) and Total amount of investment (USD) of GBR
print(D2['raised_amount_usd'].count())
print(D2['raised_amount_usd'].sum())

# %%
#Total number of investments (count) and Total amount of investment (USD) of IND
print(D3['raised_amount_usd'].count())
print(D3['raised_amount_usd'].sum())

# %%
#Grouping dataframe for USA based on main_sector and then counting based on raised_amount_mn_usd 
D1_groupBy = D1.groupby('main_sector')
D1_groupBy['raised_amount_mn_usd'].count().sort_values(ascending = False).iloc[:3]
# Out:
# main_sector
# Others                                     2950
# Social, Finance, Analytics, Advertising    2714
# Cleantech / Semiconductors                 2300
# Name: raised_amount_mn_usd, dtype: int64

# %% [markdown]
# The top 3 main_sector based on the count of investments for USA are : `Others`, `Social, Finance, Analytics, Advertising` and `Cleantech / Semiconductors`

# %%
#Grouping dataframe for GBR based on main_sector and then counting based on raised_amount_mn_usd 
D2_groupBy = D2.groupby('main_sector')
D2_groupBy['raised_amount_mn_usd'].count().sort_values(ascending = False).iloc[:3]
# Out:
# main_sector
# Others                                     147
# Social, Finance, Analytics, Advertising    133
# Cleantech / Semiconductors                 128
# Name: raised_amount_mn_usd, dtype: int64

# %% [markdown]
# The top 3 main_sector based on the count of investments for GBR are : `Others`, `Social, Finance, Analytics, Advertising` and `Cleantech / Semiconductors`

# %%
#Grouping dataframe for IND based on main_sector and then counting based on raised_amount_mn_usd 
D3_groupBy = D3.groupby('main_sector')
D3_groupBy['raised_amount_mn_usd'].count().sort_values(ascending = False).iloc[:3]
# Out:
# main_sector
# Others                                     110
# Social, Finance, Analytics, Advertising     60
# News, Search and Messaging                  52
# Name: raised_amount_mn_usd, dtype: int64

# %% [markdown]
# The top 3 main_sector based on the count of investments for IND are : `Others`, `Social, Finance, Analytics, Advertising` and `News, Search and Messaging`

# %%
#Name of the company in USA for Others Sector, which is top in amount invested

top_sector_D1 = D1.loc[D1['main_sector'] == 'Others'].sort_values(by = "Total Amount Invested", ascending = False).iloc[0]
top_sector_D1['name']
# Out:
# '17zuoye'

# %%
#Name of the company in GBR for Others Sector, which is top in amount invested

top_sector_D2 = D2.loc[D2['main_sector'] == 'Others'].sort_values(by = "Total Amount Invested", ascending = False).iloc[0]
top_sector_D2['name']
# Out:
# 'peak'

# %%
#Name of the company in IND for Others Sector, which is top in amount invested

top_sector_D3 = D3.loc[D3['main_sector'] == 'Others'].sort_values(by = "Total Amount Invested", ascending = False).iloc[0]
top_sector_D3['name']
# Out:
# 'treebo hotels'

# %%
#Name of the company in USA for "Social, Finance, Analytics, Advertising" Sector, which is top in amount invested.

second_top_sector_D1 = D1.loc[D1['main_sector'] == 'Social, Finance, Analytics, Advertising'].sort_values(by = "Total Amount Invested", ascending = False).iloc[0]
second_top_sector_D1['name']
# Out:
# 'h2o.ai'

# %%
#Name of the company in GBR for "Social, Finance, Analytics, Advertising" Sector, which is top in amount invested.

second_top_sector_D2 = D2.loc[D2['main_sector'] == 'Social, Finance, Analytics, Advertising'].sort_values(by = "Total Amount Invested", ascending = False).iloc[0]
second_top_sector_D2['name']
# Out:
# 'aihit'

# %%
#Name of the company in IND for "Social, Finance, Analytics, Advertising" Sector, which is top in amount invested.

second_top_sector_D3 = D3.loc[D3['main_sector'] == 'Social, Finance, Analytics, Advertising'].sort_values(by = "Total Amount Invested", ascending = False).iloc[0]
second_top_sector_D3['name']
# Out:
# 'coverfox insurance'

# %% [markdown]
# # Checkpoint 6: Plots
